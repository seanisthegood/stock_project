# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV
df = pd.read_csv("/stats_output.csv")

# Define metrics and their labels
metrics = ['AvgProfit', 'WinRate', 'ProfitPerDay']
labels = {
    'AvgProfit': 'Average Profit',
    'WinRate': 'Winning Percentage',
    'ProfitPerDay': 'Profit per Day'
}
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 2025-05-24 23:28:30.441 system_profiler[34480:1341980] CoreText note: Client requested name ".AlBayanPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.442 system_profiler[34480:1341980] CoreText note: Set a breakpoint on CTFontLogSystemFontNameRequest to debug.
# 2025-05-24 23:28:30.452 system_profiler[34480:1341980] CoreText note: Client requested name ".AlBayanPUA-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.466 system_profiler[34480:1341980] CoreText note: Client requested name ".AlNilePUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.482 system_profiler[34480:1341980] CoreText note: Client requested name ".AlNilePUA-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.495 system_profiler[34480:1341980] CoreText note: Client requested name ".AlTarikhPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.501 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleColorEmojiUI", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.511 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.519 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.527 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.536 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-UltraLight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.546 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.552 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-SemiBold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.558 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.564 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-ExtraBold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.570 system_profiler[34480:1341980] CoreText note: Client requested name ".AppleSDGothicNeoI-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.670 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.679 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.688 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.694 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.700 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.707 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.714 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.720 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.728 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIDisplay-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.772 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIText-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.780 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIText-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.794 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIText-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.805 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIText-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.815 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIText-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.827 system_profiler[34480:1341980] CoreText note: Client requested name ".ArabicUIText-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.842 system_profiler[34480:1341980] CoreText note: Client requested name ".ArialHebrewDeskInterface", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.853 system_profiler[34480:1341980] CoreText note: Client requested name ".ArialHebrewDeskInterface-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.862 system_profiler[34480:1341980] CoreText note: Client requested name ".ArialHebrewDeskInterface-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.871 system_profiler[34480:1341980] CoreText note: Client requested name ".BaghdadPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.883 system_profiler[34480:1341980] CoreText note: Client requested name ".BeirutPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.899 system_profiler[34480:1341980] CoreText note: Client requested name ".DamascusPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.908 system_profiler[34480:1341980] CoreText note: Client requested name ".DamascusPUAMedium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.920 system_profiler[34480:1341980] CoreText note: Client requested name ".DamascusPUALight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.932 system_profiler[34480:1341980] CoreText note: Client requested name ".DamascusPUASemiBold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.943 system_profiler[34480:1341980] CoreText note: Client requested name ".DamascusPUABold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.952 system_profiler[34480:1341980] CoreText note: Client requested name ".DecoTypeNaskhPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.962 system_profiler[34480:1341980] CoreText note: Client requested name ".DiwanKufiPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.971 system_profiler[34480:1341980] CoreText note: Client requested name ".FarahPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.982 system_profiler[34480:1341980] CoreText note: Client requested name ".GeezaProInterface", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:30.993 system_profiler[34480:1341980] CoreText note: Client requested name ".GeezaProInterface-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.001 system_profiler[34480:1341980] CoreText note: Client requested name ".GeezaProInterface-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.010 system_profiler[34480:1341980] CoreText note: Client requested name ".GeezaProPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.024 system_profiler[34480:1341980] CoreText note: Client requested name ".GeezaProPUA-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.117 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.144 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-MediumP4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.163 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.175 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.190 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-UltraLightP2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.208 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Italic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.221 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-MediumItalicP4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.237 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.248 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.261 system_profiler[34480:1341980] CoreText note: Client requested name ".HelveticaNeueDeskInterface-BoldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.268 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.281 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.290 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.297 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.303 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W0", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.310 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W5", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.317 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W6", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.326 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W7", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.337 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W8", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.349 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraKakuInterface-W9", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.356 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraginoSansGBInterface-W3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.362 system_profiler[34480:1341980] CoreText note: Client requested name ".HiraginoSansGBInterface-W6", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.371 system_profiler[34480:1341980] CoreText note: Client requested name ".Keyboard", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.385 system_profiler[34480:1341980] CoreText note: Client requested name ".KufiStandardGKPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.437 system_profiler[34480:1341980] CoreText note: Client requested name ".LucidaGrandeUI", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.455 system_profiler[34480:1341980] CoreText note: Client requested name ".LucidaGrandeUI-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.463 system_profiler[34480:1341980] CoreText note: Client requested name ".MunaPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.469 system_profiler[34480:1341980] CoreText note: Client requested name ".MunaPUABold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.479 system_profiler[34480:1341980] CoreText note: Client requested name ".MunaPUABlack", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.488 system_profiler[34480:1341980] CoreText note: Client requested name ".NadeemPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.508 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.516 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.530 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-RegularItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.540 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-MediumItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.550 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.557 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.566 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.576 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.587 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-SemiboldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.595 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-BoldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.604 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-HeavyItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.612 system_profiler[34480:1341980] CoreText note: Client requested name ".NewYork-BlackItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.621 system_profiler[34480:1341980] CoreText note: Client requested name ".NotoNastaliqUrduUI", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.633 system_profiler[34480:1341980] CoreText note: Client requested name ".NotoNastaliqUrduUI-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.654 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangHK-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.663 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangHK-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.677 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangHK-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.692 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangHK-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.703 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangHK-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.712 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangHK-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.726 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangSC-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.737 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangSC-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.744 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangSC-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.751 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangSC-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.760 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangSC-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.766 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangSC-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.777 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangTC-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.784 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangTC-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.795 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangTC-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.804 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangTC-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.810 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangTC-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.818 system_profiler[34480:1341980] CoreText note: Client requested name ".PingFangTC-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.827 system_profiler[34480:1341980] CoreText note: Client requested name ".SanaPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.834 system_profiler[34480:1341980] CoreText note: Client requested name ".SavoyeLetPlainCC", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.856 system_profiler[34480:1341980] CoreText note: Client requested name "..SFCompactDisplay-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.867 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.875 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.882 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.891 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.898 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.905 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.914 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.926 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.937 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactDisplay-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.959 system_profiler[34480:1341980] CoreText note: Client requested name "..SFCompactRounded-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.974 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.981 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.990 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:31.997 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.004 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.012 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.020 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.028 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.036 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactRounded-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.054 system_profiler[34480:1341980] CoreText note: Client requested name "..SFCompactText-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.069 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.083 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-RegularG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.094 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-RegularG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.103 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-RegularG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.111 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.118 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.131 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.142 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.160 system_profiler[34480:1341980] CoreText note: Client requested name "..SFCompactText-Italic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.174 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-RegularItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.182 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-RegularItalicG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.192 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-RegularItalicG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.200 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-RegularItalicG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.207 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-MediumItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.214 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-LightItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.225 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-ThinItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.238 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-UltralightItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.247 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.255 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.264 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-BoldG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.274 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-BoldG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.283 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-BoldG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.294 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.303 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-SemiboldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.311 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-BoldItalic", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:32.318 system_profiler[34480:1341980] CoreText note: Client requested name ".SFCompactText-BoldItalicG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# ...
# 2025-05-24 23:28:33.667 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-LightG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.689 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-LightG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.701 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-LightG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.711 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-LightG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.724 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-Thin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.738 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-ThinG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.749 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-ThinG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.758 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-ThinG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.768 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-ThinG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.783 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-Ultralight", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.796 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-UltralightG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.805 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-UltralightG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.819 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-UltralightG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.836 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-UltralightG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.847 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-Ultrathin", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.859 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.877 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-SemiboldG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.891 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-SemiboldG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.902 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-SemiboldG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.912 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-SemiboldG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.927 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.944 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-BoldG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.954 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-BoldG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.970 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-BoldG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:33.989 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-BoldG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.001 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.013 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-HeavyG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.027 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-HeavyG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.044 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-HeavyG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.054 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-HeavyG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.063 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-UltrathinG1", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.076 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-UltrathinG2", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.089 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-UltrathinG3", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.099 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-UltrathinG4", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.109 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSRounded-Black", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.123 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSTextCondensed-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.141 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSTextCondensed-Medium", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.158 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSTextCondensed-Light", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.175 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSTextCondensed-Semibold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.195 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSTextCondensed-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2025-05-24 23:28:34.214 system_profiler[34480:1341980] CoreText note: Client requested name ".SFNSTextCondensed-Heavy", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Load your CSV
# ----> 5 df = pd.read_csv("stats_output.csv")
#       7 # Define metrics and their labels
#       8 metrics = ['AvgProfit', 'WinRate', 'ProfitPerDay']
#
# File ~/jupyter_env/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/jupyter_env/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/jupyter_env/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/jupyter_env/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/jupyter_env/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stats_output.csv'

# %%
# Get unique risk levels
risk_levels = sorted(df['RiskLevel'].unique())

# Create subplots (one per risk level)
fig, axes = plt.subplots(len(risk_levels), 1, figsize=(10, 5 * len(risk_levels)), sharex=True)

# Plot each risk level
for i, risk in enumerate(risk_levels):
    ax = axes[i]
    subset = df[df['RiskLevel'] == risk]
    
    for metric in metrics:
        ax.plot(subset['Label'], subset[metric], marker='o', label=labels[metric])
    
    ax.set_title(f"Risk Level {risk}")
    ax.set_ylabel("Value")
    ax.legend()
    ax.grid(True)

plt.xlabel("Label")
plt.tight_layout()
plt.show()
