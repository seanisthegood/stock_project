# %%
import pandas as pd
import plotly.graph_objects as go

# %%
import plotly.io as pio
pio.renderers.default = 'notebook'  # or 'iframe' or 'colab' depending on what works

# %%
# Load CSV
df = pd.read_csv('/Users/seanyboy/Documents/IntellliJ/Class_Project/Data/AAL_Daily.csv', parse_dates=['Date'])

fig = go.Figure(data=[go.Candlestick(
    x=df['Date'],
    open=df['Open'],
    high=df['High'],
    low=df['Low'],
    close=df['Close'],
    increasing_line_color='green',
    decreasing_line_color='red',
    increasing_fillcolor='rgba(0,0,0,0)',
    decreasing_fillcolor='rgba(0,0,0,0)',
    line_width=1  # thin lines
)])

# Update layout to match your screenshot's clean style
fig.update_layout(
    title='',
    xaxis_title='',
    yaxis_title='',
    showlegend=False,
    plot_bgcolor='white',
    paper_bgcolor='white',
    xaxis=dict(
        showgrid=False,
        showticklabels=False,
        zeroline=False
    ),
    yaxis=dict(
        showgrid=False,
        showticklabels=False,
        zeroline=False
    ),
    xaxis_rangeslider_visible=False,
    margin=dict(l=0, r=0, t=0, b=0)
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="85b60a99-6a60-44f5-ba09-56a0fb8b3684" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("85b60a99-6a60-44f5-ba09-56a0fb8b3684")) {                    Plotly.newPlot(                        "85b60a99-6a60-44f5-ba09-56a0fb8b3684",                        [{"close":{"dtype":"f8","bdata":"ahX9oZm5QkBqFf2hmZlDQKuYSj\u002fh2kNAAAAAAACAQ0B+w0SDFE5DQJbqAl5m5kJAluoCXmZmQUC\u002ffLJiuH5BQJbqAl5mBkFAAAAAAAAAPkAAAAAAAAA\u002fQAN5dvnWYz5APQrXo3A9PUDsUbgehWs9QIXrUbgeBT9AAAAAAAAAP0AAAAAAAEA+QAN5dvnW4zxAAAAAAAAAPU
# ...
